# %% [markdown]
# # Seattle Airbnbn Listings Analysis_CRISP-DM
# - __Author: Fan Yuan__
# - __Created: 07/02/2019__
#
# ## Context
# Since 2008, guests and hosts have used Airbnb to travel in a more unique, personalized way. As part of the Airbnb Inside initiative, this dataset describes the listing activity of homestays in Seattle, WA. This project is going to analyse the Seattle Airbnb Listings to see if any insight from data could help Airbnb optimize the business.
#
# In this project, __CRISP-DM (Cross-Industry Standard Process for Data Mining)__ will be applied to better frame the problem and get the insight from data analysis.
#
# - __CRISP-DM__:
#     * Business Understanding
#     * Data Understanding
#     * Data Preparation
#     * Modeling
#     * Evaluation
#     * Deployment
#
#
# ## To analyse:
# This project will analyse the Seattle Airbnbn Listings as following:
#
# - Describe the vibe of each Seattle neighborhood using listing descriptions, is there any key factors which largely affect the listing price
#     * Explore if there's any common characteristics among Seattle neighborhood, and it might be opportunities for Airbnb to get insight of what kind of neighbourhood are more likely to host Airbnb
#     * Probably also look at if there's any preference on neighbourhood among visitors
#
#
# - Find the busiest times of the year to visit Seattle and by how much prices spike
#     * For Airbnb, it'll be a loss if the available room can't satisfy the user demand within busy season
#     * Also, the scale of price increase will be helpful for business opportunities
#
#
# - Verify that if there's a general upward trend of both new Airbnb listings and total Airbnb visitors to Seattle
#     * Get an insight on how the host and vistors change in period
#
#
# - What factor relates to higher guests review most?
#     * If we could get an idea of which kind of hosts and room are more likely to get a higher rivew from guests, as Airbnb, they can recommend or advice the hosts to get better review next time

# %% [markdown]
# ## Load data & take an initial view
#
# First, load in dataset and have a cursory overview to understand the data.
#
# Three data sets are provided:
# - listings: including full descriptions and average review score
# - calendar: including listing id and the price and availability for that day
# - reviews: including unique id for each reviewer and detailed comments

# %%
# Import libraries necessary 
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import copy
import re

import plotly as py
import plotly.offline as offline
import plotly.graph_objs as go
from plotly.offline import iplot, plot, init_notebook_mode, download_plotlyjs

from sklearn.feature_extraction.text import CountVectorizer

# Pretty display for notebooks
# %matplotlib inline
matplotlib.style.use('ggplot')

# %%
# Load the listings, calendar, reviews data
listings = pd.read_csv('seattle/listings.csv')

# Display the first several rows of dataset
display(listings.head())
# display(listings.shape)
display(listings.info())
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview        ...         \
# 0                                                NaN        ...
# 1  Queen Anne is a wonderful, truly functional vi...        ...
# 2  Upper Queen Anne is a charming neighborhood fu...        ...
# 3                                                NaN        ...
# 4  We are in the beautiful neighborhood of Queen ...        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                10.0                f     NaN         WASHINGTON
# 1                10.0                f     NaN         WASHINGTON
# 2                10.0                f     NaN         WASHINGTON
# 3                 NaN                f     NaN         WASHINGTON
# 4                 9.0                f     NaN         WASHINGTON
#
#   instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                f            moderate                              f
# 1                f              strict                              t
# 2                f              strict                              f
# 3                f            flexible                              f
# 4                f              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
# id                                  3818 non-null int64
# listing_url                         3818 non-null object
# scrape_id                           3818 non-null int64
# last_scraped                        3818 non-null object
# name                                3818 non-null object
# summary                             3641 non-null object
# space                               3249 non-null object
# description                         3818 non-null object
# experiences_offered                 3818 non-null object
# neighborhood_overview               2786 non-null object
# notes                               2212 non-null object
# transit                             2884 non-null object
# thumbnail_url                       3498 non-null object
# medium_url                          3498 non-null object
# picture_url                         3818 non-null object
# xl_picture_url                      3498 non-null object
# host_id                             3818 non-null int64
# host_url                            3818 non-null object
# host_name                           3816 non-null object
# host_since                          3816 non-null object
# host_location                       3810 non-null object
# host_about                          2959 non-null object
# host_response_time                  3295 non-null object
# host_response_rate                  3295 non-null object
# host_acceptance_rate                3045 non-null object
# host_is_superhost                   3816 non-null object
# host_thumbnail_url                  3816 non-null object
# host_picture_url                    3816 non-null object
# host_neighbourhood                  3518 non-null object
# host_listings_count                 3816 non-null float64
# host_total_listings_count           3816 non-null float64
# host_verifications                  3818 non-null object
# host_has_profile_pic                3816 non-null object
# host_identity_verified              3816 non-null object
# street                              3818 non-null object
# neighbourhood                       3402 non-null object
# neighbourhood_cleansed              3818 non-null object
# neighbourhood_group_cleansed        3818 non-null object
# city                                3818 non-null object
# state                               3818 non-null object
# zipcode                             3811 non-null object
# market                              3818 non-null object
# smart_location                      3818 non-null object
# country_code                        3818 non-null object
# country                             3818 non-null object
# latitude                            3818 non-null float64
# longitude                           3818 non-null float64
# is_location_exact                   3818 non-null object
# property_type                       3817 non-null object
# room_type                           3818 non-null object
# accommodates                        3818 non-null int64
# bathrooms                           3802 non-null float64
# bedrooms                            3812 non-null float64
# beds                                3817 non-null float64
# bed_type                            3818 non-null object
# amenities                           3818 non-null object
# square_feet                         97 non-null float64
# price                               3818 non-null object
# weekly_price                        2009 non-null object
# monthly_price                       1517 non-null object
# security_deposit                    1866 non-null object
# cleaning_fee                        2788 non-null object
# guests_included                     3818 non-null int64
# extra_people                        3818 non-null object
# minimum_nights                      3818 non-null int64
# maximum_nights                      3818 non-null int64
# calendar_updated                    3818 non-null object
# has_availability                    3818 non-null object
# availability_30                     3818 non-null int64
# availability_60                     3818 non-null int64
# availability_90                     3818 non-null int64
# availability_365                    3818 non-null int64
# calendar_last_scraped               3818 non-null object
# number_of_reviews                   3818 non-null int64
# first_review                        3191 non-null object
# last_review                         3191 non-null object
# review_scores_rating                3171 non-null float64
# review_scores_accuracy              3160 non-null float64
# review_scores_cleanliness           3165 non-null float64
# review_scores_checkin               3160 non-null float64
# review_scores_communication         3167 non-null float64
# review_scores_location              3163 non-null float64
# review_scores_value                 3162 non-null float64
# requires_license                    3818 non-null object
# license                             0 non-null float64
# jurisdiction_names                  3818 non-null object
# instant_bookable                    3818 non-null object
# cancellation_policy                 3818 non-null object
# require_guest_profile_picture       3818 non-null object
# require_guest_phone_verification    3818 non-null object
# calculated_host_listings_count      3818 non-null int64
# reviews_per_month                   3191 non-null float64
# dtypes: float64(17), int64(13), object(62)
# memory usage: 2.7+ MB
# None

# %% [markdown]
# ### Do an initial categorization on features in listings data set:
#
# - DESCRIPTIONS - name, summary, space, description
# - HOST - host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost
# - HOME DETAILS - property_type, room_type, accomodates, bathrooms, bedrooms, beds, bed_type, amenities
# - LISTING ELEMENTS - price, cleaning_fee, extra_people, minimum_nights, maximum_nights, instant_bookable, cancellation policy
# - OUTCOME VARIABLES - 'review_scores_rating', 'review_scores_accuracy', review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value'

# %%
# Load calendar data
calendar = pd.read_csv('seattle/calendar.csv')
display(calendar.head())
display(calendar.info())
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
# listing_id    1393570 non-null int64
# date          1393570 non-null object
# available     1393570 non-null object
# price         934542 non-null object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB
# None

# %%
# Check if all 'f' available have 'NaN' in price
# calendar.price[calendar['available']=='f'].isna().mean()
calendar_available_check = calendar.groupby('available')['price'].count().reset_index()
calendar_available_check
# Out:
#   available   price
# 0         f       0
# 1         t  934542

# %% [markdown]
# It shows all 'f' available in calendar dataset will have NaN in price column

# %%
# Check if each listing_id has same rows of availability entries
calendar_date_check = calendar.groupby('listing_id')['date'].count().reset_index()
display(calendar_date_check.head())
calendar_date_check['date'].value_counts()
# Out:
#    listing_id  date
# 0        3335   365
# 1        4291   365
# 2        5682   365
# 3        6606   365
# 4        7369   365
# 365    3818
# Name: date, dtype: int64

# %% [markdown]
# From the result above, it shows that for each of 3818 listing_id there are 1-year (365) calendar price. This can be utilized later to investigate if there's upward or downward trend within the year period.

# %%
# Load reviews data
reviews = pd.read_csv('seattle/reviews.csv')
display(reviews.head())
display(reviews.info())
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84849 entries, 0 to 84848
# Data columns (total 6 columns):
# listing_id       84849 non-null int64
# id               84849 non-null int64
# date             84849 non-null object
# reviewer_id      84849 non-null int64
# reviewer_name    84849 non-null object
# comments         84831 non-null object
# dtypes: int64(3), object(3)
# memory usage: 3.9+ MB
# None

# %% [markdown]
# ## Clean the data for further analysis
#
# ### Listings data
# Clean up the useless columns from 92 fields to ones that are valuable and helpful for later anlaysis and prediction.

# %%
# Check the null percentage to see if need to abandon any columns
listing_null = listings.isnull().sum()/listings.shape[0]
listing_null[listing_null > 0].sort_values(ascending=False).head(20)
# Out:
# license                        1.000000
# square_feet                    0.974594
# monthly_price                  0.602672
# security_deposit               0.511262
# weekly_price                   0.473808
# notes                          0.420639
# neighborhood_overview          0.270299
# cleaning_fee                   0.269775
# transit                        0.244631
# host_about                     0.224987
# host_acceptance_rate           0.202462
# review_scores_accuracy         0.172342
# review_scores_checkin          0.172342
# review_scores_value            0.171818
# review_scores_location         0.171556
# review_scores_cleanliness      0.171032
# review_scores_communication    0.170508
# review_scores_rating           0.169460
# reviews_per_month              0.164222
# first_review                   0.164222
# dtype: float64

# %% [markdown]
# In order to get an idea of how is the vibe of each neighborhood, aggregate all neighborhood_review of each neighborhood together and extract the most popular words from corpors.

# %%
# Get an overview of neighborhood number
listings.neighbourhood.value_counts()
# Out:
# Capitol Hill                 351
# Ballard                      213
# Belltown                     204
# Minor                        192
# Queen Anne                   187
# Fremont                      148
# Wallingford                  143
# University District          107
# First Hill                   105
# Stevens                       98
# North Beacon Hill             95
# Lower Queen Anne              83
# Central Business District     81
# Greenwood                     79
# Columbia City                 61
# Ravenna                       59
# Phinney Ridge                 56
# Magnolia                      55
# Green Lake                    52
# Atlantic                      50
# North Admiral                 48
# Mount Baker                   46
# Leschi                        44
# Eastlake                      41
# Maple Leaf                    41
# Madrona                       40
# Pike Place Market             39
# The Junction                  36
# Bryant                        32
# Seward Park                   32
#                             ...
# Highland Park                 12
# Licton Springs                12
# Olympic Hills                 12
# Yesler Terrace                12
# Westlake                      12
# North Beach/Blue Ridge        11
# High Point                    11
# Windermere                    10
# Fauntleroy                    10
# Seaview                        9
# Meadowbrook                    9
# Laurelhurst                    9
# Cedar Park                     8
# Riverview                      8
# Georgetown                     7
# South Delridge                 7
# Interbay                       7
# View Ridge                     6
# Holly Park                     6
# Broadway                       5
# Brighton                       5
# Pinehurst                      3
# Arbor Heights                  3
# Industrial District            3
# South Park                     2
# South Beacon Hill              2
# Pike Market                    2
# Fairmount Park                 1
# North College Park             1
# Roxhill                        1
# Name: neighbourhood, Length: 81, dtype: int64

# %%
# Describe the vibe of each Seattle neighborhood using listing descriptions

# Exclude NaN overview
nonull_neighbor_review = listings[listings['neighborhood_overview'].notna()]
nonull_neighbor_review = nonull_neighbor_review.loc[:,['neighbourhood','neighborhood_overview']]


nonull_neighbor_review = nonull_neighbor_review.groupby('neighbourhood').agg(lambda x: tuple(x))\
                            .applymap(list).reset_index()
nonull_neighbor_review.head()

# Save the neighbors name list
neighbors = list(nonull_neighbor_review['neighbourhood'].apply(lambda x: x.lower()))

nonull_neighbor_review.head(10)
# Out:
#    neighbourhood                              neighborhood_overview
# 0           Alki  [Alki Beach is an awesome place during the sum...
# 1  Arbor Heights  [nice residential neighborhood, away from the ...
# 2       Atlantic  [We are located in the Central District betwee...
# 3        Ballard  [Ballard is a quaint, Norwegian neighborhood. ...
# 4       Belltown  [This neighborhood is AWESOME! We are: - 1 str...
# 5    Bitter Lake  [Family neighborhood in North Seattle - less h...
# 6       Brighton  [Our neighborhood is great! We are located in ...
# 7      Broadview  [Quiet and convenient!, The residential neighb...
# 8       Broadway  [Being a block away from interesting Broadway ...
# 9         Bryant  [Rosie's Roost is an ideal location for playin...

# %%
# function to preprocess the neighborhood_overview

def pre_process(text_list):

    clean_list = []

    for text in text_list:
        # lowercase
        text = text.lower()
    
        # remove tags
        text = re.sub("<!--?.*?-->","",text)
    
        # remove special characters and digits
        text = re.sub("(\\d|\\W)+"," ",text)
        
        # remove neighborhood name in review
        text = text.split()
        
        # remove 'neighbor' name from review
        text = ' '.join([word for word in text if word not in neighbors])
        
        clean_list.append(text)
    return clean_list

# %%
# nonull_neighbor_review['neighborhood_overview'] = nonull_neighbor_review['neighborhood_overview'].astype(str)
nonull_neighbor_review['neighborhood_overview'] = nonull_neighbor_review['neighborhood_overview']\
                                                    .apply(lambda s: pre_process(s))
nonull_neighbor_review.head(10)
# Out:
#    neighbourhood                              neighborhood_overview
# 0           Alki  [beach is an awesome place during the summer a...
# 1  Arbor Heights  [nice residential neighborhood away from the h...
# 2       Atlantic  [we are located in the central district betwee...
# 3        Ballard  [is a quaint norwegian neighborhood plenty of ...
# 4       Belltown  [this neighborhood is awesome we are street aw...
# 5    Bitter Lake  [family neighborhood in north seattle less hus...
# 6       Brighton  [our neighborhood is great we are located in t...
# 7      Broadview  [quiet and convenient, the residential neighbo...
# 8       Broadway  [being a block away from interesting gives us ...
# 9         Bryant  [rosie s roost is an ideal location for playin...

# %%
# Function to extract the post popular word in neighbor_review for each neighbor
def extract_review(review, num):
    cv = CountVectorizer(stop_words='english')
    word_count_vector=cv.fit_transform(review)
    
    top = list(cv.vocabulary_.keys())[:num]
    return top

# %%
# Extract top 10 popular words in neighborhood_review for each neighbor
nonull_neighbor_review['vibe'] = nonull_neighbor_review['neighborhood_overview']\
                                    .apply(lambda x: extract_review(x,10))

neighbor_vibe = nonull_neighbor_review.drop('neighborhood_overview', axis=1)
neighbor_vibe.head(10)
# Out:
#    neighbourhood                                               vibe
# 0           Alki  [beach, awesome, place, summer, winter, popula...
# 1  Arbor Heights  [nice, residential, neighborhood, away, hustle...
# 2       Atlantic  [located, central, district, puget, sound, lak...
# 3        Ballard  [quaint, norwegian, neighborhood, plenty, uniq...
# 4       Belltown  [neighborhood, awesome, street, away, major, p...
# 5    Bitter Lake  [family, neighborhood, north, seattle, hustle,...
# 6       Brighton  [neighborhood, great, located, diverse, zip, c...
# 7      Broadview  [quiet, convenient, residential, neighborhood,...
# 8       Broadway  [block, away, interesting, gives, quiet, locat...
# 9         Bryant  [rosie, roost, ideal, location, playing, explo...

# %%
# Print the vibe of each neighbor
for i in range(neighbor_vibe.shape[0]):
    print('Neighbourhood: '+ neighbor_vibe['neighbourhood'][i])
    print('Vibe: '+ str(', '.join(neighbor_vibe['vibe'][i])) + '\n')
# Out:
# Neighbourhood: Alki
# Vibe: beach, awesome, place, summer, winter, popular, open, water, swim, area
#
# Neighbourhood: Arbor Heights
# Vibe: nice, residential, neighborhood, away, hustle, bustle, close, walk, awesome, park
#
# Neighbourhood: Atlantic
# Vibe: located, central, district, puget, sound, lake, washington, location, offers, quick
#
# Neighbourhood: Ballard
# Vibe: quaint, norwegian, neighborhood, plenty, unique, restaurants, shops, cafes, local, major
#
# Neighbourhood: Belltown
# Vibe: neighborhood, awesome, street, away, major, public, transit, routes, minute, walk
#
# Neighbourhood: Bitter Lake
# Vibe: family, neighborhood, north, seattle, hustle, bustle, traffic, easy, jaunt, sights
#
# Neighbourhood: Brighton
# Vibe: neighborhood, great, located, diverse, zip, code, usa, according, news, reports
#
# Neighbourhood: Broadview
# Vibe: quiet, convenient, residential, neighborhood, northern, crown, hill, carkeek, park, minutes
#
# Neighbourhood: Broadway
# Vibe: block, away, interesting, gives, quiet, location, instant, access, action, want
#
# Neighbourhood: Bryant
# Vibe: rosie, roost, ideal, location, playing, exploring, sea, hawks, huskies, game
#
# Neighbourhood: Capitol Hill
# Vibe: walking, distance, best, restaurants, bars, seattle, offer, quick, access, downtown
#
# Neighbourhood: Cedar Park
# Vibe: proximity, lake, city, access, neighborhood, restaurants, bars, groceries, easy, freeway
#
# Neighbourhood: Central Business District
# Vibe: things, probably, want, experience, seattle, dont, time, pike, place, blocks
#
# Neighbourhood: Columbia City
# Vibe: located, columbia, city, diverse, zip, code, seattle, ll, surrounded, ethnic
#
# Neighbourhood: Crown Hill
# Vibe: just, miles, north, central, area, trendy, funky, quality, restaurants, great
#
# Neighbourhood: Dunlap
# Vibe: diverse, vibrant, neighborhood, city, addition, light, rail, area, older, houses
#
# Neighbourhood: Eastlake
# Vibe: seattle, floating, homes, block, away, lovely, village, like, road, follows
#
# Neighbourhood: Fairmount Park
# Vibe: close, grocery, stores, shops, bars, restaurants, art, gallery
#
# Neighbourhood: Fauntleroy
# Vibe: peace, privacy, earth, friendly, neighbors, great, mix, ages, living, generations
#
# Neighbourhood: First Hill
# Vibe: walk, score, transit, great, entertainment, walking, distance, walkable, access, swedish
#
# Neighbourhood: Fremont
# Vibe: frelard, known, wonderful, neighborhood, ridge, giving, views, olympic, mountains, puget
#
# Neighbourhood: Gatewood
# Vibe: morgan, junction, walking, distance, including, shopping, restaurants, brew, pubs, coffee
#
# Neighbourhood: Genesee
# Vibe: west, seattle, brewery, rudys, barbershop, trader, joes, budda, ruksa, thai
#
# Neighbourhood: Georgetown
# Vibe: lots, restaurants, guide, book, bars, coffee, shops, antique, eclectic, stores
#
# Neighbourhood: Green Lake
# Vibe: green, lake, beautiful, neighborhood, heart, north, seattle, fun, coffee, pub
#
# Neighbourhood: Greenwood
# Vibe: offers, walking, distance, multiple, grocery, stores, restaurants, bars, parks, amenities
#
# Neighbourhood: Haller Lake
# Vibe: love, city, close, things, quiet, bus, lines, downtown, north, seattle
#
# Neighbourhood: Harrison/Denny-Blaine
# Vibe: neighborhood, haven, want, quiet, established, relatively, close, city, center, short
#
# Neighbourhood: High Point
# Vibe: quiet, west, seattle, neighborhood, makes, fantastic, home, base, residential, local
#
# Neighbourhood: Highland Park
# Vibe: love, mountains, walk, quiet, peaceful, neighborhood, minutes, airport, miles, downtown
#
# Neighbourhood: Holly Park
# Vibe: love, neighborhood, peaceful, feels, like, beaten, path, proximity, lot, seattle
#
# Neighbourhood: Industrial District
# Vibe: minute, drive, bike, ride, experience, finest, coffee, food, seattle, offer
#
# Neighbourhood: Interbay
# Vibe: great, neighborhood, sits, right, fast, pace, downtown, seattle, diverse, neighborhoods
#
# Neighbourhood: International District
# Vibe: fun, interesting, international, neighborhood, lots, quirky, shops, tons, food, choices
#
# Neighbourhood: Laurelhurst
# Vibe: neighborhood, city, feels, like, country, quiet, walking, distance, parks, coffee
#
# Neighbourhood: Leschi
# Vibe: live, cusp, seattle, neighborhoods, home, apartment, sits, quiet, tree, lined
#
# Neighbourhood: Licton Springs
# Vibe: conveniently, located, quiet, safe, lots, street, parking, walking, blocks, greenlake
#
# Neighbourhood: Lower Queen Anne
# Vibe: hub, lower, queen, anne, contained, blocks, near, seattle, center, packed
#
# Neighbourhood: Madison Park
# Vibe: madison, park, adorable, neighborhood, restaurants, bars, bakery, salons, spas, fitness
#
# Neighbourhood: Madrona
# Vibe: house, located, min, center, madison, capitol, hill, downtown, walk, areas
#
# Neighbourhood: Magnolia
# Vibe: live, dead, end, street, house, looks, trees, experience, peace, quiet
#
# Neighbourhood: Maple Leaf
# Vibe: neighborhood, beautiful, parks, people, walking, streets, early, morning, late, evening
#
# Neighbourhood: Mathews Beach
# Vibe: residential, neighborhood, friendly, people, living, years, age, diversity, old, young
#
# Neighbourhood: Meadowbrook
# Vibe: lovely, peaceful, suburban, neighborhood, ne, seattle, quick, easy, bus, access
#
# Neighbourhood: Minor
# Vibe: vibrant, historic, neighborhood, capitol, hill, lovely, french, district, madison, valley
#
# Neighbourhood: Montlake
# Vibe: located, quiet, residential, street, neighborhood, mile, walk, university, washington, medical
#
# Neighbourhood: Mount Baker
# Vibe: great, local, cafes, eateries, nice, walk, waterfront, lake, washington, tennis
#
# Neighbourhood: North Admiral
# Vibe: neighborhoods, seattle, access, sand, beach, long, walking, biking, path, winds
#
# Neighbourhood: North Beach/Blue Ridge
# Vibe: seattle, nice, fancy, desired, north, beach, blue, ridge, area, perks
#
# Neighbourhood: North Beacon Hill
# Vibe: grocery, stores, walking, distance, lot, restaurants, studio, located, beacon, hill
#
# Neighbourhood: North College Park
# Vibe: neighborhood, ideal, half, street, houses, apartments, makes, lot, cars, parked
#
# Neighbourhood: North Delridge
# Vibe: close, quiet, residential, neighbourhood, cafe, block, restaurants, crepes, pizza, thai
#
# Neighbourhood: Olympic Hills
# Vibe: lake, city, quiet, urban, neighborhood, amenities, seattle, minus, traffic, crowd
#
# Neighbourhood: Phinney Ridge
# Vibe: phinney, ridge, neighborhood, neighborhoods, seattle, bungalow, type, homes, friendly, people
#
# Neighbourhood: Pike Place Market
# Vibe: heart, downtown, seattle, block, pike, place, market, walk, score, transit
#
# Neighbourhood: Pinehurst
# Vibe: north, seattle, location, keeps, close, downtown, just, miles, battle, traffic
#
# Neighbourhood: Pioneer Square
# Vibe: located, historic, pioneer, square, easily, walking, distance, best, restaurants, city
#
# Neighbourhood: Portage Bay
# Vibe: walk, wonderful, restaurants, party, hip, pine, pike, corridor, watch, sunset
#
# Neighbourhood: Queen Anne
# Vibe: queen, anne, wonderful, truly, functional, village, walk, coffee, groceries, night
#
# Neighbourhood: Rainier Beach
# Vibe: corner, multiple, grocery, stores, community, center, pool, lovely, kubota, gardens
#
# Neighbourhood: Ravenna
# Vibe: neighborhood, minute, walk, village, shopping, center, university, washington, seattle, children
#
# Neighbourhood: Riverview
# Vibe: love, greenbelt, property, makes, feel, like, city, minutes, downtown, car
#
# Neighbourhood: Roosevelt
# Vibe: restaurants, shops, proximity, parks, favorite, places, walk, neighborhood, cowen, playground
#
# Neighbourhood: Roxhill
# Vibe: alike, beach, west, seattle, junction, easy, bus, access, downtown, url
#
# Neighbourhood: Seaview
# Vibe: beautiful, setting, heart, west, seattle, super, safe, neighborhood, walking, distance
#
# Neighbourhood: Seward Park
# Vibe: wonderful, quiet, neighborhood, bus, blocks, away, reason, bought, house, gorgeous
#
# Neighbourhood: South Beacon Hill
# Vibe: quiet, friendly, people, abound, established, seattle, neighborhood
#
# Neighbourhood: South Delridge
# Vibe: house, located, border, coming, white, center, incidentally, best, mexican, vietnamese
#
# Neighbourhood: South Lake Union
# Vibe: walk, score, space, needle, museums, bars, restaurants, markets, steps, away
#
# Neighbourhood: South Park
# Vibe: oldest, neighborhood, lots, character, south, park, located, close, desired, places
#
# Neighbourhood: Stevens
# Vibe: unit, blocks, away, th, street, safeway, intersection, easy, access, late
#
# Neighbourhood: The Junction
# Vibe: easy, access, public, transit, driving, quick, trip, vashon, southworth, ferries
#
# Neighbourhood: University District
# Vibe: wonderful, walking, neighborhood, close, uw, grocery, stores, saturday, farmer, market
#
# Neighbourhood: Victory Heights
# Vibe: victory, heights, tree, lover, paradise, nestled, northgate, lake, city, beautiful
#
# Neighbourhood: View Ridge
# Vibe: outdoor, lovers, neighborhood, safe, welcoming, beautiful, views, lake, washington, right
#
# Neighbourhood: Wallingford
# Vibe: hood, short, walk, main, drags, world, dining, drinking, options, check
#
# Neighbourhood: Wedgewood
# Vibe: located, northeast, seattle, wedgwood, peaceful, residential, neighborhood, miles, university, washington
#
# Neighbourhood: Westlake
# Vibe: area, walkable, downtown, close, transit, amazon, sensitive, contents, hidden, quieter
#
# Neighbourhood: Windermere
# Vibe: apartment, located, quaint, quite, neighborhood, close, uw, village, district, parks
#
# Neighbourhood: Yesler Terrace
# Vibe: located, seattle, university, area, secured, friendly, surrounding, college, students, small

# %% [markdown]
# ### Calendar data
#
# In order to plot the average price within a year to display how Airbnb price move, here need to:
# - Remove the '$' in price column to make it correctly formatted for calculation
# - Drop the NaN in price column
# - Transfer the date format for better plot.

# %%
# Replace the '$' and ',' in price column
calendar['price'] = calendar['price'].str.replace('$','')
calendar['price'] = calendar['price'].str.replace(',','').astype('float64')

# %%
calendar_day_mean = calendar.groupby('date')[['price']].mean()
calendar_day_mean.head()
# Out:
#                  price
# date
# 2016-01-04  122.085879
# 2016-01-05  120.681307
# 2016-01-06  120.928258
# 2016-01-07  120.958896
# 2016-01-08  127.640853

# %%
offline.init_notebook_mode(connected=True)

offline.iplot({
    "data": [go.Scatter(x=calendar_day_mean.index, y=calendar_day_mean.price)],
    "layout": go.Layout(title='Price Trend by Date',
                           xaxis=dict(title='Date'),
                           yaxis=dict(title='Avg'))
})
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="f1f17ccd-ac02-4462-b108-35d0e003782a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f1f17ccd-ac02-4462-b108-35d0e003782a")) {
#                     Plotly.newPlot(
#                         'f1f17ccd-ac02-4462-b108-35d0e003782a',
#                         [{"type": "scatter", "uid": "bea76a74-b2c1-4b61-8cbd-6e1cd0cceed4", "x": ["2016-01-04", "2016-01-05", "2016-01-06", "2016-01-07", "2016-01-08", "2016-01-09", "2016-01-10", "2016-01-11", "2016-01-12", "2016-01-13", "2016-01-14", "2016-01-15", "2016-01-16", "2016-01-17", "2016-01-18", "2016-01-19", "2016-01-20", "2016-01-21", "2016-01-22", "2016-01-23", "2016-01-24", "2016-01-25", "2016-01-26", "2016-01-27", "2016-01-28", "2016-01-29", "2016-01-30", "2016-01-31", "2016-02-01", "2016-02-02", "2016-02-03", "2016-02-04", "2016-02-05", "2016-02-06", "2016-02-07", "2016-02-08", "2016-02-09", "2016-02-10", "2016-02-11", "2016-02-12", "2016-02-13", "2016-02-14", "2016-02-15", "2016-02-16", "2016-02-17", "2016-02-18", "2016-02-19", "2016-02-20", "2016-02-21", "2016-02-22", "2016-02-23", "2016-02-24", "2016-02-25", "2016-02-26", "2016-02-27", "2016-02-28", "2016-02-29", "2016-03-01", "2016-03-02", "2016-03-03", "2016-03-04", "2016-03-05", "2016-03-06", "2016-03-07", "2016-03-08", "2016-03-09", "2016-03-10", "2016-03-11", "2016-03-12", "2016-03-13", "2016-03-14", "2016-03-15", "2016-03-16", "2016-03-17", "2016-03-18", "2016-03-19", "2016-03-20", "2016-03-21", "2016-03-22", "2016-03-23", "2016-03-24", "2016-03-25", "2016-03-26", "2016-03-27", "2016-03-28", "2016-03-29", "2016-03-30", "2016-03-31", "2016-04-01", "2016-04-02", "2016-04-03", "2016-04-04", "2016-04-05", "2016-04-06", "2016-04-07", "2016-04-08", "2016-04-09", "2016-04-10", "2016-04-11", "2016-04-12", "2016-04-13", "2016-04-14", "2016-04-15", "2016-04-16", "2016-04-17", "2016-04-18", "2016-04-19", "2016-04-20", "2016-04-21", "2016-04-22", "2016-04-23", "2016-04-24", "2016-04-25", "2016-04-26", "2016-04-27", "2016-04-28", "2016-04-29", "2016-04-30", "2016-05-01", "2016-05-02", "2016-05-03", "2016-05-04", "2016-05-05", "2016-05-06", "2016-05-07", "2016-05-08", "2016-05-09", "2016-05-10", "2016-05-11", "2016-05-12", "2016-05-13", "2016-05-14", "2016-05-15", "2016-05-16", "2016-05-17", "2016-05-18", "2016-05-19", "2016-05-20", "2016-05-21", "2016-05-22", "2016-05-23", "2016-05-24", "2016-05-25", "2016-05-26", "2016-05-27", "2016-05-28", "2016-05-29", "2016-05-30", "2016-05-31", "2016-06-01", "2016-06-02", "2016-06-03", "2016-06-04", "2016-06-05", "2016-06-06", "2016-06-07", "2016-06-08", "2016-06-09", "2016-06-10", "2016-06-11", "2016-06-12", "2016-06-13", "2016-06-14", "2016-06-15", "2016-06-16", "2016-06-17", "2016-06-18", "2016-06-19", "2016-06-20", "2016-06-21", "2016-06-22", "2016-06-23", "2016-06-24", "2016-06-25", "2016-06-26", "2016-06-27", "2016-06-28", "2016-06-29", "2016-06-30", "2016-07-01", "2016-07-02", "2016-07-03", "2016-07-04", "2016-07-05", "2016-07-06", "2016-07-07", "2016-07-08", "2016-07-09", "2016-07-10", "2016-07-11", "2016-07-12", "2016-07-13", "2016-07-14", "2016-07-15", "2016-07-16", "2016-07-17", "2016-07-18", "2016-07-19", "2016-07-20", "2016-07-21", "2016-07-22", "2016-07-23", "2016-07-24", "2016-07-25", "2016-07-26", "2016-07-27", "2016-07-28", "2016-07-29", "2016-07-30", "2016-07-31", "2016-08-01", "2016-08-02", "2016-08-03", "2016-08-04", "2016-08-05", "2016-08-06", "2016-08-07", "2016-08-08", "2016-08-09", "2016-08-10", "2016-08-11", "2016-08-12", "2016-08-13", "2016-08-14", "2016-08-15", "2016-08-16", "2016-08-17", "2016-08-18", "2016-08-19", "2016-08-20", "2016-08-21", "2016-08-22", "2016-08-23", "2016-08-24", "2016-08-25", "2016-08-26", "2016-08-27", "2016-08-28", "2016-08-29", "2016-08-30", "2016-08-31", "2016-09-01", "2016-09-02", "2016-09-03", "2016-09-04", "2016-09-05", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-10", "2016-09-11", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-17", "2016-09-18", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-24", "2016-09-25", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-01", "2016-10-02", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-0 ...

# %% [markdown]
# Obviously, there's a slow but continuous __upward trend__ of Seattle Airbnb price from Jan to Jul where reaching the peak, and then it goes down slowly a little after that. In order to see the trend more clearly in high level, aggregate the data into monthly data.

# %%
# Resample calendar data by month
calendar_month_mean = copy.copy(calendar)

calendar_month_mean['date'] = pd.to_datetime(calendar_month_mean['date'])
calendar_month_mean = calendar_month_mean.set_index("date")

calendar_month_mean = pd.DataFrame(calendar_month_mean['price'].resample('M').mean())
calendar_month_mean
# Out:
#                  price
# date
# 2016-01-31  121.568409
# 2016-02-29  124.293927
# 2016-03-31  128.644488
# 2016-04-30  135.097005
# 2016-05-31  139.538183
# 2016-06-30  147.473137
# 2016-07-31  152.094150
# 2016-08-31  150.656594
# 2016-09-30  143.255949
# 2016-10-31  137.031939
# 2016-11-30  135.688738
# 2016-12-31  137.251835
# 2017-01-31  136.882590

# %%
offline.iplot({
    "data": [go.Scatter(x=calendar_month_mean.index, y=calendar_month_mean.price)],
    "layout": go.Layout(title='Price Trend by Month',
                           xaxis=dict(title='Month'),
                           yaxis=dict(title='Avg'))
})
# Out:
# <div>
#
#
#             <div id="b4504e96-2596-4b19-b0a9-a9bb730da267" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b4504e96-2596-4b19-b0a9-a9bb730da267")) {
#                     Plotly.newPlot(
#                         'b4504e96-2596-4b19-b0a9-a9bb730da267',
#                         [{"type": "scatter", "uid": "41fe5415-e43e-46f0-835f-349c0d48624c", "x": ["2016-01-31", "2016-02-29", "2016-03-31", "2016-04-30", "2016-05-31", "2016-06-30", "2016-07-31", "2016-08-31", "2016-09-30", "2016-10-31", "2016-11-30", "2016-12-31", "2017-01-31"], "y": [121.56840932493796, 124.29392670585507, 128.64448759798898, 135.09700540526322, 139.5381825911893, 147.47313707213505, 152.09414998248496, 150.65659423422008, 143.25594852807913, 137.03193915427352, 135.6887380777696, 137.2518349203432, 136.8825903825904]}],
#                         {"title": {"text": "Price Trend by Month"}, "xaxis": {"title": {"text": "Month"}}, "yaxis": {"title": {"text": "Avg"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('b4504e96-2596-4b19-b0a9-a9bb730da267');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# From the plot above, it clearly shows a peak in Jul with an average of $152. Compared to the lowest price given the period data, it increases about $20 on average.
#
# So we could check the availability of room by time using calendar data to see if the number of available is low when the price goes upward. Also, we could find when the busiest time of visitors going to Seattle by counting how many rooms not available along with time.

# %%
calendar_month_available = calendar.groupby('date')['price'].count().reset_index()
calendar_month_available.columns = ['date', 'available_room']

calendar_month_available['date'] = pd.to_datetime(calendar_month_available['date'])
calendar_month_available = calendar_month_available.set_index('date')
calendar_month_available = calendar_month_available.resample('M')[['available_room']].mean()

calendar_month_available
# Out:
#             available_room
# date
# 2016-01-31     2115.678571
# 2016-02-29     2528.310345
# 2016-03-31     2707.677419
# 2016-04-30     2534.566667
# 2016-05-31     2579.709677
# 2016-06-30     2574.800000
# 2016-07-31     2394.258065
# 2016-08-31     2462.806452
# 2016-09-30     2574.866667
# 2016-10-31     2659.290323
# 2016-11-30     2726.000000
# 2016-12-31     2808.419355
# 2017-01-31     2849.000000

# %%
offline.iplot({
    "data": [go.Scatter(x=calendar_month_avai`lable.index, y=calendar_month_available.available_room)],
    "layout": go.Layout(title='Available room number by Month',
                           xaxis=dict(title='Month'),
                           yaxis=dict(title='Avg'))
})
# Out:
# <div>
#
#
#             <div id="319221e8-2ba8-4de6-beea-32178f832018" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("319221e8-2ba8-4de6-beea-32178f832018")) {
#                     Plotly.newPlot(
#                         '319221e8-2ba8-4de6-beea-32178f832018',
#                         [{"type": "scatter", "uid": "7d78fc3a-747b-4cdc-b55f-de0006b715a6", "x": ["2016-01-31", "2016-02-29", "2016-03-31", "2016-04-30", "2016-05-31", "2016-06-30", "2016-07-31", "2016-08-31", "2016-09-30", "2016-10-31", "2016-11-30", "2016-12-31", "2017-01-31"], "y": [2115.6785714285716, 2528.310344827586, 2707.6774193548385, 2534.5666666666666, 2579.7096774193546, 2574.8, 2394.2580645161293, 2462.8064516129034, 2574.866666666667, 2659.2903225806454, 2726.0, 2808.4193548387098, 2849.0]}],
#                         {"title": {"text": "Available room number by Month"}, "xaxis": {"title": {"text": "Month"}}, "yaxis": {"title": {"text": "Avg"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('319221e8-2ba8-4de6-beea-32178f832018');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Combined with the plot of price trend analysis, obviously, the busiest season locates in Jul since the available room number gets the lowest point and the room price also raise to the highest point.

# %% [markdown]
# ### Review data
#
# id and reviewer_name columns in review data set are not very helpful for analysis actually. Here use review count number along with time to see if there's an upward trend in total visitors to Seattle

# %%
reviews_count = copy.copy(reviews)
reviews_count['date'] = pd.to_datetime(reviews_count['date'])

reviews_count = reviews_count.set_index('date')
reviews_count = reviews_count.resample('Q')[['id']].count()
reviews_count
# Out:
#                id
# date
# 2009-06-30      2
# 2009-09-30      4
# 2009-12-31     11
# 2010-03-31     13
# 2010-06-30     37
# 2010-09-30    110
# 2010-12-31     94
# 2011-03-31     88
# 2011-06-30    212
# 2011-09-30    514
# 2011-12-31    355
# 2012-03-31    371
# 2012-06-30    770
# 2012-09-30   1294
# 2012-12-31    816
# 2013-03-31    756
# 2013-06-30   1635
# 2013-09-30   2900
# 2013-12-31   1786
# 2014-03-31   2156
# 2014-06-30   3956
# 2014-09-30   8848
# 2014-12-31   5405
# 2015-03-31   6061
# 2015-06-30  12019
# 2015-09-30  21528
# 2015-12-31  12885
# 2016-03-31    223

# %%
offline.iplot({
    "data": [go.Scatter(x=reviews_count.index, y=reviews_count.id)],
    "layout": go.Layout(title='Review number by Quater',
                           xaxis=dict(title='Quater'),
                           yaxis=dict(title='Review Num'))
})
# Out:
# <div>
#
#
#             <div id="3cfaab1c-d344-4d9a-870e-d70e994d0a7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3cfaab1c-d344-4d9a-870e-d70e994d0a7b")) {
#                     Plotly.newPlot(
#                         '3cfaab1c-d344-4d9a-870e-d70e994d0a7b',
#                         [{"type": "scatter", "uid": "a8726bef-112c-496a-9f48-79fa00ae631e", "x": ["2009-06-30", "2009-09-30", "2009-12-31", "2010-03-31", "2010-06-30", "2010-09-30", "2010-12-31", "2011-03-31", "2011-06-30", "2011-09-30", "2011-12-31", "2012-03-31", "2012-06-30", "2012-09-30", "2012-12-31", "2013-03-31", "2013-06-30", "2013-09-30", "2013-12-31", "2014-03-31", "2014-06-30", "2014-09-30", "2014-12-31", "2015-03-31", "2015-06-30", "2015-09-30", "2015-12-31", "2016-03-31"], "y": [2, 4, 11, 13, 37, 110, 94, 88, 212, 514, 355, 371, 770, 1294, 816, 756, 1635, 2900, 1786, 2156, 3956, 8848, 5405, 6061, 12019, 21528, 12885, 223]}],
#                         {"title": {"text": "Review number by Quater"}, "xaxis": {"title": {"text": "Quater"}}, "yaxis": {"title": {"text": "Review Num"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('3cfaab1c-d344-4d9a-870e-d70e994d0a7b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# The plot above clearly shows that there's a general upward trend of total Airbnb visitors to Seattle reaching the peak around 2015 summer.
